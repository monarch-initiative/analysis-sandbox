# %% [markdown]
# ### Phenotypic Co-occurrence
# One measure enabled by the HPOA disease to phenotype data is phenotypic co-occurrence.  Phenotypic co-occurrence is of interest because it allows us to hypothesize that there is a dependent relationship between two phenotypes.  Although it does not imply causality, it may indicate a causal relationship between two phenotypes and and a third (or more) latent variables, or a causual relationship between two phenotypes. For example, _progressive muscle weakness_ causes _falls_.  Or an alternative example, there is a biological process and/or environmental factor that is causes allergies and asthma to co-occurr.  The latter is of interest in Monarch because we can query biological pathways and processes (GO, Reactome, etc.) related to phenotypes by joining gene-disease-phenotype relationships.  In addition, this type of analysis could  be useful to weight gene to phenotype associations where phenotypes co-occur in a mendelian disease where we have identified a causual gene to disease association.  This analysis could also be used to hypothesize pleiotropic effects.
#
# For simplicitiy, we will treat all phenotypes and diseases as flat (or leaf nodes) in our disease to phenotype association data.  In practice we know this is not correct, and both phenotype groups and disease groups appear in the association data.
#
# #### Approach
# We will query the HPOA association data using the Monarch Neo4J database.  These values may differ from querying the raw dataset due to merging equivalent diseases in MONDO.
#
# This analysis assumes we are starting with a phenotype of interest.  Although a more comprehensive analyses, as in generating a co-occurrence matrix, may also be useful.
#
#
# #### About this notebook
# This notebook uses the _Prominent nasal bridge_ as an example phenotype.  This can be changed in the second cell to analyze different phenotypes.
#
# Dependencies:
#
# * pip install requests
# * pip install pandas
# * pip install neo4j-driver

# %%
import requests

# Query the Monarch database for co-occurrence of prominent nasal bridge and other phenotypes
# This can performed using a count aggregate function in cypher

phenotype = "HP:0000426" # Prominent nasal bridge

SCIGRAPH = "https://scigraph-data-dev.monarchinitiative.org/scigraph/"
scigraph_exec = SCIGRAPH + "cypher/execute"
scigraph_resolve = SCIGRAPH + "cypher/resolve"

# The WHERE p1 <> p2 because clique merging of diseases causes
# duplicate edges, need to fix
cypher_query = """
    MATCH (disease:disease)-[:RO:0002200]->(p1:Node{iri:'%s'}),
          (disease)-[:RO:0002200]->(p2:Node)
    WHERE p1 <> p2
    RETURN p2.label as phenotype, COUNT(DISTINCT(disease)) as disease_count
    ORDER BY disease_count DESC
""" % phenotype

params = {
    'cypherQuery': cypher_query,
    'limit': 10
}

scigraph_req = requests.get(scigraph_exec, params=params)
print(scigraph_req.text) # Default format is ascii text table, but we can get back json
# Out:
# +--------------------------------------------------+
# | phenotype                        | disease_count |
# +--------------------------------------------------+
# | "Short stature"                  | 67            |
# | "Global developmental delay"     | 67            |
# | "Microcephaly"                   | 67            |
# | "Intellectual disability"        | 65            |
# | "Seizures"                       | 50            |
# | "Micrognathia"                   | 48            |
# | "Downslanted palpebral fissures" | 46            |
# | "High palate"                    | 45            |
# | "Cryptorchidism"                 | 44            |
# | "Low-set ears"                   | 43            |
# +--------------------------------------------------+
# 10 rows

# %% [markdown]
# #### Normalization
# We know that the distribution of phenotypes across diseases is not uniform.  In other words, some phenotypes are annnotated to diseases more often than others.  Therefore, we need to normalize this data.  This is not to be confused with the frequency that a patient presents with a phenotype or expressivity.
#
# Two common methods for normalizing co-occurrence data are Jaccard similarity and Cosine similarity.
#
# We define these two approaches as:
#
# $$Jaccard(P1,P2) = \frac{\mid \ P1 \cap P2 \ \mid}{\mid\  P1 \mid + \mid P2 \mid - \mid P1 \cap P2 \ \mid }$$
#
# Where
# $$ \mid \  P \mid = \text{Number of diseases annotated to phenotype P} $$
#
# For cosine similarity we will use the Ochiai coefficient, defined as:
#
# $$\text{Ochiai coefficient(P1,P2)} = \frac{\mid P1 \cap P2 \mid}{\sqrt{\mid \ P1 \mid \times \mid P2 \ \mid}}$$
#
# #### Approach
# This can achieved in pure cypher, but we may consider creating a function on the server.

# %%
# Normalize with jaccard similarity
cypher_query = """
    MATCH (disease:disease)-[:RO:0002200]->(p1:Node{iri:'%s'}),
          (disease)-[:RO:0002200]->(p2:Phenotype)
    WHERE p2 <> p1
    WITH p2, COUNT(DISTINCT(disease)) as co_count
    MATCH (disease:disease)-[:RO:0002200]->(p1:Node{iri:'%s'})
    WITH COUNT(DISTINCT(disease)) as p1_count, p2, co_count
    MATCH (disease:disease)-[:RO:0002200]->(p2)
    WITH COUNT(DISTINCT(disease)) as p2_count, p1_count, p2, co_count
    RETURN p2.label as phenotype, p1_count, p2_count, co_count as intersection,
           toFloat(co_count)/((p1_count + p2_count)-co_count) as normal_coef
    ORDER BY normal_coef DESC
    """ % (phenotype, phenotype)

params = {
    'cypherQuery': cypher_query,
    'limit': 10
}

scigraph_req = requests.get(scigraph_exec, params=params)
print(scigraph_req.text) # Default format is ascii text table, but we can get back json
# Out:
# +---------------------------------------------------------------------------------------------+
# | phenotype                        | p1_count | p2_count | intersection | normal_coef         |
# +---------------------------------------------------------------------------------------------+
# | "Long face"                      | 129      | 117      | 27           | 0.1232876712328767  |
# | "Highly arched eyebrow"          | 129      | 102      | 22           | 0.10526315789473684 |
# | "Downslanted palpebral fissures" | 129      | 372      | 46           | 0.1010989010989011  |
# | "High palate"                    | 129      | 429      | 45           | 0.08771929824561403 |
# | "Thin vermilion border"          | 129      | 110      | 19           | 0.08636363636363636 |
# | "Posteriorly rotated ears"       | 129      | 184      | 24           | 0.08304498269896193 |
# | "Short philtrum"                 | 129      | 151      | 21           | 0.08108108108108109 |
# | "Macrotia"                       | 129      | 191      | 24           | 0.08108108108108109 |
# | "Narrow mouth"                   | 129      | 210      | 25           | 0.07961783439490445 |
# | "Sloping forehead"               | 129      | 89       | 16           | 0.07920792079207921 |
# +---------------------------------------------------------------------------------------------+
# 10 rows

# %%
# Normalize with ochiai coefficient
cypher_query = """
    MATCH (disease:disease)-[:RO:0002200]->(p1:Node{iri:'%s'}),
          (disease)-[:RO:0002200]->(p2:Phenotype)
    WHERE p1 <> p2
    WITH DISTINCT p1, p2, disease
    WITH p2, COUNT(DISTINCT(disease)) as co_count
    MATCH (disease:disease)-[:RO:0002200]->(p1:Node{iri:'%s'})
    WITH COUNT(DISTINCT(disease)) as p1_count, p2, co_count
    MATCH (disease:disease)-[:RO:0002200]->(p2)
    WITH COUNT(DISTINCT(disease)) as p2_count, p1_count, p2, co_count
    RETURN p2.label as phenotype, p1_count, p2_count, co_count as intersection,
    toFloat(co_count)/sqrt(p1_count * p2_count) as normal_coef
    ORDER BY normal_coef DESC
    """ % (phenotype, phenotype)

params = {
    'cypherQuery': cypher_query,
    'limit': 10
}

scigraph_req = requests.get(scigraph_exec, params=params)
print(scigraph_req.text) # Default format is ascii text table, but we can get back json
# Out:
# +---------------------------------------------------------------------------------------------+
# | phenotype                        | p1_count | p2_count | intersection | normal_coef         |
# +---------------------------------------------------------------------------------------------+
# | "Long face"                      | 129      | 117      | 27           | 0.21977383072747697 |
# | "Downslanted palpebral fissures" | 129      | 372      | 46           | 0.20998656367149773 |
# | "Microcephaly"                   | 129      | 941      | 67           | 0.19230259103012684 |
# | "Highly arched eyebrow"          | 129      | 102      | 22           | 0.19179078635417854 |
# | "High palate"                    | 129      | 429      | 45           | 0.19128856646721754 |
# | "Low-set ears"                   | 129      | 488      | 43           | 0.1713814012647042  |
# | "Short stature"                  | 129      | 1187     | 67           | 0.17122003759530918 |
# | "Ptosis"                         | 129      | 499      | 42           | 0.16554046181613402 |
# | "Micrognathia"                   | 129      | 657      | 48           | 0.16487837460195826 |
# | "Cryptorchidism"                 | 129      | 584      | 44           | 0.16030659803408318 |
# +---------------------------------------------------------------------------------------------+
# 10 rows

# %% [markdown]
# #### Results
# The original results showed several neurological abnormalities: seizures, global development delay, intellecutal disability.  In contrast, after normalization the majority of co-occurring phenotypes are related to morphilogical abnormalities of the head, with the exception of cryptorchidism.  It should be noted that cryptorchidism and microcephaly are phenotype groups, and considering disease to phenotype associations of their subclasses may downweight their co-occurrence.
#
# #### Normalization on phenotypic frequency
# For a single disease to phenotype association, the HPOAs provide a frequency field, defined as the frequency of patients that show a particular clinical feature. Examples are Obligate, Frequent, and Occasional.
#
# We can use this data to further weight/normalize phenotypic co-occurrence data.  For example, if two phenotypes occur "very frequently" in the same disease, this would be weighted higher than if one phenotype occurs very frequently, and one occurs occasionally.  We consider the intersection the minimum frequency between two phenotypes.  In addition, the total disease count will be adjusted to account for frequency.
#
# As a test we will set the following weights:
#
# | Frequency    | Definition     | Weight |
# |:-------------|:----------------|:--------|
# |Excluded      |present in 0%    | 0      |
# |Very rare     |present in 1-4%  |. 25    |
# |Occasional    |present in 5-29% |1.7    |
# |Frequent      |present in 30-79%|5.45    |
# |Very frequent |present in 80-99%|8.95    |
# |Obligate      |present in 100%|10    |
# |Not provided  ||4    |

# %%
import pandas as pd
from neo4j.v1 import GraphDatabase

# Frequency weight map
freq_weights = {
    'HP:0040285': 0,
    'HP:0040284': .25,
    'HP:0040283': 1.7,
    'HP:0040282': 5.45,
    'HP:0040281': 8.95,
    'HP:0040280': 10,
    'unknown':    4 # Not sure how to boost this
}

# Result table
result_table = pd.DataFrame()

# Note this query would be a lot shorter if frequencies were edge properties
cypher_query = """
      MATCH (disease:disease)-[:RO:0002200]->(p1:Node{iri:'%s'}),
            (disease)-[:RO:0002200]->(p2:Phenotype)
      WHERE p1 <> p2
      WITH DISTINCT p1, p2, disease
      OPTIONAL MATCH (assoc:association)-[:OBAN:association_has_subject]->(disease),
            (assoc)-[:OBAN:association_has_object]->(p1),
            (assoc)-[:OBAN:association_has_predicate]->(has_pheno:Node{iri:'http://purl.obolibrary.org/obo/RO_0002200'}),
            (assoc)-[::frequencyOfPhenotype]->(freq_p1)
      WITH p1, p2, disease, freq_p1
      OPTIONAL MATCH (assoc:association)-[:OBAN:association_has_subject]->(disease),
            (assoc)-[:OBAN:association_has_object]->(p2),
            (assoc)-[:OBAN:association_has_predicate]->(has_pheno:Node{iri:'http://purl.obolibrary.org/obo/RO_0002200'}),
            (assoc)-[::frequencyOfPhenotype]->(freq_p2)
      RETURN p1, p2, disease, freq_p1, freq_p2
      """ % phenotype

params = {
    'cypherQuery': cypher_query
}

scigraph_req = requests.get(scigraph_resolve, params=params)
resolved_query = scigraph_req.text # Resolve curies to IRIs

scigraph_bolt = "bolt://neo4j.monarchinitiative.org:443"
driver = GraphDatabase.driver(scigraph_bolt, auth=("neo4j", "password"))

def get_scigraph_results(query):
    with driver.session() as session:
        with session.begin_transaction() as tx:
            for record in tx.run(query):
                yield record

for result in get_scigraph_results(resolved_query):
    row = {}
    row['query_phenotype'] = result['p1']['label']
    row['phenotype'] = result['p2']['label']
    row['disease'] = result['disease']['label']
    row['qphenotype_curie'] = result['p1']['iri'].replace("http://purl.obolibrary.org/obo/HP_", "HP:")
    row['phenotype_curie'] = result['p2']['iri'].replace("http://purl.obolibrary.org/obo/HP_", "HP:")
    row['disease_curie'] = result['disease']['iri'].replace("http://purl.obolibrary.org/obo/MONDO_", "MONDO:")

    if result['freq_p1'] is not None:
        freq_p1_curie = \
            result['freq_p1']['iri'].replace("http://purl.obolibrary.org/obo/HP_", "HP:")
    else:
        freq_p1_curie = 'unknown'
    if result['freq_p2'] is not None:
        freq_p2_curie = \
            result['freq_p2']['iri'].replace("http://purl.obolibrary.org/obo/HP_", "HP:")
    else:
        freq_p2_curie = 'unknown'
        
    row['q_phenotype_frequency'] = freq_weights[freq_p1_curie]
    row['phenotype_frequency'] = freq_weights[freq_p2_curie]
    
    result_table = result_table.append(row, ignore_index=True)
    
result_table.head()
# Out:
#                                              disease  disease_curie  \
# 0  dentinogenesis imperfecta-short stature-hearin...  MONDO:0019102
# 1  dentinogenesis imperfecta-short stature-hearin...  MONDO:0019102
# 2  dentinogenesis imperfecta-short stature-hearin...  MONDO:0019102
# 3  dentinogenesis imperfecta-short stature-hearin...  MONDO:0019102
# 4  dentinogenesis imperfecta-short stature-hearin...  MONDO:0019102
#
#                           phenotype phenotype_curie  phenotype_frequency  \
# 0             Cone-shaped epiphysis      HP:0010579                 8.95
# 1     Intellectual disability, mild      HP:0001256                 8.95
# 2             Abnormal facial shape      HP:0001999                 8.95
# 3                    Short philtrum      HP:0000322                 8.95
# 4  Sensorineural hearing impairment      HP:0000407                 8.95
#
#    q_phenotype_frequency qphenotype_curie         query_phenotype
# 0                   8.95       HP:0000426  Prominent nasal bridge
# 1                   8.95       HP:0000426  Prominent nasal bridge
# 2                   8.95       HP:0000426  Prominent nasal bridge
# 3                   8.95       HP:0000426  Prominent nasal bridge
# 4                   8.95       HP:0000426  Prominent nasal bridge

# %%
aggregate_table = pd.DataFrame()

phenotypes = result_table['phenotype'].unique()

for pheno in phenotypes:
    group_by_pheno = result_table[result_table['phenotype'] == pheno]
    intersection = group_by_pheno.loc[:, ['phenotype_frequency', 'q_phenotype_frequency']].min(axis=1).sum()
    row = {
        'phenotype': pheno,
        'phenotype_curie': group_by_pheno.iloc[0]['phenotype_curie'],
        'intersection': intersection
    }
    aggregate_table = aggregate_table.append(row, ignore_index=True)

aggregate_table.sort_values(by=['intersection'], ascending=False).head(10)
# Out:
#      intersection                       phenotype phenotype_curie
# 10         308.85      Global developmental delay      HP:0001263
# 86         285.90                    Microcephaly      HP:0000252
# 9          285.90                   Short stature      HP:0004322
# 38         275.35         Intellectual disability      HP:0001249
# 19         213.90                    Micrognathia      HP:0000347
# 101        212.20  Downslanted palpebral fissures      HP:0000494
# 18         192.50                  Cryptorchidism      HP:0000028
# 17         185.75                     High palate      HP:0000218
# 56         180.30                    Low-set ears      HP:0000369
# 44         176.40                          Ptosis      HP:0000508

# %% [markdown]
# The top ten look similar to our original top ten list. However, we still need to normalize this data.  For the next step we will leverage our solr cache.  Solr/Golr is useful because we can toggle between treating phenotype disease annotations as flat or querying grouping classes (when applicable, such as microcephaly).

# %%
import math

# Pull down whole pivot table
solr = 'https://solr-dev.monarchinitiative.org/solr/golr/select/'
params = {
  "facet.pivot": "object,frequency",
  "fq": [
    "subject_category:disease",
    "object_category:phenotype"
  ],
  "rows": "0",
  "q": "*:*",
  "facet.limit": "12000", # Should get all of HPO
  "f.object_closure.facet.prefix": "HP",
  "facet.method": "enum",
  "facet.mincount": "1",
  "facet": "true",
  "wt": "json",
  "facet.sort": "count"
};

solr_req = requests.get(solr, params=params)
pivot_table = solr_req.json()

aggregate_table['p2_count'] = 0
phenotype_ids = result_table['phenotype_curie'].unique()


def calculate_weighted_frequency(facet):
    count = (int(facet['count']) - sum([freq['count'] for freq in facet['pivot']])) * freq_weights['unknown']
    for freq in facet['pivot']:
        count += (freq['count'] * freq_weights[freq['value']])
    return count

for facet in pivot_table['facet_counts']['facet_pivot']['object,frequency']:
    if facet['value'] == phenotype:
        if 'pivot' in facet:
            count = calculate_weighted_frequency(facet)
        else:
            count = int(facet['count']) * freq_weights['unknown']
        aggregate_table['p1_count'] = count
    elif facet['value'] in phenotype_ids:
        if 'pivot' in facet:
            count = calculate_weighted_frequency(facet)
        else:
            count = int(facet['count']) * freq_weights['unknown']
        aggregate_table.loc[(aggregate_table['phenotype_curie'] == facet['value']), "p2_count"] = count

def calculate_jaccard(intersection, count1, count2):
    return intersection / ((count1 + count2) - intersection)

def calcuate_ochiai(intersection, count1, count2):
    return intersection / math.sqrt(count1 * count2)


aggregate_table['jaccard_sim'] = aggregate_table.apply(
        func=lambda row: calculate_jaccard(
                              row['intersection'],
                              row['p1_count'],
                              row['p2_count']),
        axis=1
)
    
aggregate_table['ochiai_coeff'] = aggregate_table.apply(
        func=lambda row: calcuate_ochiai(
                              row['intersection'],
                              row['p1_count'],
                              row['p2_count']),
        axis=1
)

aggregate_table.sort_values(by=['jaccard_sim'], ascending=False).head(15)
# Out:
#      intersection                       phenotype phenotype_curie  p2_count  \
# 335        104.45                       Long face      HP:0000276    517.25
# 101        212.20  Downslanted palpebral fissures      HP:0000494   1788.05
# 3          101.50                  Short philtrum      HP:0000322    708.80
# 160         68.90           Low anterior hairline      HP:0000294    293.85
# 17         185.75                     High palate      HP:0000218   1889.00
# 63          88.05           Thin vermilion border      HP:0000233    571.00
# 83         116.15                        Macrotia      HP:0000400    970.85
# 57         116.75                    Narrow mouth      HP:0000160   1020.75
# 188         76.35           Highly arched eyebrow      HP:0002553    456.30
# 147         99.25        Posteriorly rotated ears      HP:0000358    795.50
# 421         75.70       Underdeveloped nasal alae      HP:0000430    495.80
# 105         69.90                Sloping forehead      HP:0000340    436.25
# 49         164.10               Wide nasal bridge      HP:0000431   1885.90
# 48          95.45                Blepharophimosis      HP:0000581    837.10
# 13          83.45                  Arachnodactyly      HP:0001166    653.30
#
#      p1_count  jaccard_sim  ochiai_coeff
# 335    638.55     0.099348      0.181744
# 101    638.55     0.095827      0.198590
# 3      638.55     0.081470      0.150871
# 160    638.55     0.079792      0.159059
# 17     638.55     0.079319      0.169128
# 63     638.55     0.078511      0.145819
# 83     638.55     0.077783      0.147518
# 57     638.55     0.075686      0.144610
# 188    638.55     0.074963      0.141445
# 147    638.55     0.074356      0.139256
# 421    638.55     0.071506      0.134538
# 105    638.55     0.069559      0.132438
# 49     638.55     0.069524      0.149538
# 48     638.55     0.069157      0.130554
# 13     638.55     0.069058      0.129203

# %%
aggregate_table.sort_values(by=['ochiai_coeff'], ascending=False).head(15)
# Out:
#      intersection                       phenotype phenotype_curie  p2_count  \
# 101        212.20  Downslanted palpebral fissures      HP:0000494   1788.05
# 335        104.45                       Long face      HP:0000276    517.25
# 86         285.90                    Microcephaly      HP:0000252   4470.40
# 17         185.75                     High palate      HP:0000218   1889.00
# 160         68.90           Low anterior hairline      HP:0000294    293.85
# 3          101.50                  Short philtrum      HP:0000322    708.80
# 113        168.50                      Epicanthus      HP:0000286   1977.30
# 49         164.10               Wide nasal bridge      HP:0000431   1885.90
# 56         180.30                    Low-set ears      HP:0000369   2288.95
# 10         308.85      Global developmental delay      HP:0001263   6719.80
# 18         192.50                  Cryptorchidism      HP:0000028   2629.50
# 44         176.40                          Ptosis      HP:0000508   2218.15
# 83         116.15                        Macrotia      HP:0000400    970.85
# 63          88.05           Thin vermilion border      HP:0000233    571.00
# 19         213.90                    Micrognathia      HP:0000347   3373.95
#
#      p1_count  jaccard_sim  ochiai_coeff
# 101    638.55     0.095827      0.198590
# 335    638.55     0.099348      0.181744
# 86     638.55     0.059278      0.169217
# 17     638.55     0.079319      0.169128
# 160    638.55     0.079792      0.159059
# 3      638.55     0.081470      0.150871
# 113    638.55     0.068850      0.149957
# 49     638.55     0.069524      0.149538
# 56     638.55     0.065630      0.149135
# 10     638.55     0.043812      0.149098
# 18     638.55     0.062590      0.148558
# 44     638.55     0.065814      0.148220
# 83     638.55     0.077783      0.147518
# 63     638.55     0.078511      0.145819
# 19     638.55     0.056310      0.145728

# %% [markdown]
# For this example, adding frequency data does not seem to affect the results much with the exception that _low anterior hairline_ is upranked in the frequency aware lists.
#
# Follow up questions:
# - What cutoff is considered significant for grouping phenotypes (or should we generate a matrix and cluster?)
# - What genes are associated with this group of phenotypes?
# - What processes and pathways are associated with these genes?

# %%
# Get the top two hits
top_phenotypes = aggregate_table.sort_values(
    by=['jaccard_sim'],
    ascending=False)['phenotype_curie'][0:2]

# Add query phenotype
pheno_group = top_phenotypes.tolist()
pheno_group.append(phenotype)

def get_solr_docs(solr, params):
    resultCount = params['rows']
    while params['start'] < resultCount:
        solr_request = requests.get(solr, params=params)
        response = solr_request.json()
        resultCount = response['response']['numFound']
        params['start'] += params['rows']
        for doc in response['response']['docs']:
            yield doc
            
# Get intersection of genes
def get_gene_intersect(phenotypes, solr):
    genes = dict()
    is_first = True
    for term in phenotypes:
        params = {
            'wt': 'json',
            'rows': 500,
            'start': 0,
            'q': '*:*',
            'fl': 'subject, subject_label',
            'fq': ['subject_category:"gene"',
                   'object_closure: "{}"'.format(term)
                  ]
        }
        temp_dict = {}
        for doc in get_solr_docs(solr, params):
            temp_dict[doc['subject']] = doc['subject_label']
        
        if is_first:
            genes = temp_dict
        else:
            gene_set = genes.keys() & temp_dict.keys()
            genes = {k: temp_dict[k] for k in gene_set}
        is_first = False
    return genes

genes = get_gene_intersect(pheno_group, solr)

list(genes.values())
# Out:
# ['OTUD6B',
#  'MED12',
#  'TMEM237',
#  'CEP152',
#  'FBN1',
#  'TBX1',
#  'CEP290',
#  'SNAP29',
#  'SIN3A',
#  'EBF3',
#  'MKS1',
#  'HERC1',
#  'RECQL4',
#  'NPHP1',
#  'SATB2',
#  'BDH1',
#  'KAT6B']

# %%
import itertools
# Get all related pathways and GO processes

def get_facet_table(solr, params):
    """
    fetch and convert facet table to dictionary
    """
    results = {}
    solr_request = requests.get(solr, params=params)
    response = solr_request.json()
    for facet in response['facet_counts']['facet_fields'].values():
        temp_dict = dict(itertools.zip_longest(*[iter(facet)] * 2, fillvalue=""))
        results = {**results, **temp_dict}
    return results

gene_or_filter = ""
for gene in genes.keys():
    gene_or_filter += 'OR subject_closure:"{}" '.format(gene)
gene_or_filter = gene_or_filter[3:]

# Go mol function params
params = {
    'wt': 'json',
    'rows': 0,
    'q': '*:*',
    'facet': 'true',
    'facet.sort': 'count',
    'facet.method': 'enum',
    'facet.mincount': '1',
    'facet.limit': '3000',
    'facet.field': 'object_label',
    'fl': 'subject, subject_label',
    'fq': [gene_or_filter,
           'relation:"RO:0002331"',
           
          ]
}

go_functions = get_facet_table(solr, params)
go_functions
# Out:
# {'AURKA Activation by TPX2': 4,
#  'Adaptive Immune System': 1,
#  'Anchoring of the basal body to the plasma membrane': 8,
#  'Antigen processing: Ubiquitination & Proteasome degradation': 2,
#  'Autophagy - animal': 1,
#  'Butanoate metabolism': 1,
#  'Cell Cycle': 2,
#  'Cell Cycle, Mitotic': 2,
#  'Centrosome maturation': 2,
#  'Chromatin modifying enzymes': 1,
#  'Chromatin organization': 1,
#  'Cilium Assembly': 4,
#  'Class I MHC mediated antigen processing & presentation': 1,
#  'DNA duplex unwinding': 1,
#  'DNA repair': 1,
#  'DNA replication': 2,
#  'DNA strand renaturation': 1,
#  'Degradation of the extracellular matrix': 2,
#  'Developmental Biology': 1,
#  'Elastic fibre formation': 2,
#  'Epigenetic regulation of gene expression': 1,
#  'Extracellular matrix organization': 1,
#  'Factors involved in megakaryocyte development and platelet production': 2,
#  'Fatty acid, triacylglycerol, and ketone body metabolism': 3,
#  'G2/M Transition': 2,
#  'G2/M transition of mitotic cell cycle': 2,
#  'Gene Expression': 2,
#  'Generic Transcription Pathway': 2,
#  'HATs acetylate histones': 2,
#  "Hedgehog 'off' state": 2,
#  'Hemostasis': 1,
#  "Huntington's disease": 1,
#  'Immune System': 3,
#  'Innate Immune System': 2,
#  'Integrin cell surface interactions': 2,
#  'Intra-Golgi and retrograde Golgi-to-ER traffic': 1,
#  'Intra-Golgi traffic': 2,
#  'Ketone body metabolism': 1,
#  'Loss of Nlp from mitotic centrosomes': 4,
#  'Loss of proteins required for interphase microtubule organization from the centrosome': 4,
#  'Membrane Trafficking': 1,
#  'Metabolic pathways': 1,
#  'Metabolism': 3,
#  'Metabolism of lipids and lipoproteins': 3,
#  'Mitotic G2-G2/M phases': 2,
#  'Molecules associated with elastic fibres': 2,
#  'Negative epigenetic regulation of rRNA expression': 1,
#  'Neutrophil degranulation': 4,
#  'NoRC negatively regulates rRNA expression': 2,
#  'Organelle biogenesis and maintenance': 4,
#  'PPARA activates gene expression': 2,
#  'Post-translational protein phosphorylation': 2,
#  'RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function': 2,
#  'RUNX2 regulates osteoblast differentiation': 2,
#  'Recruitment of NuMA to mitotic centrosomes': 4,
#  'Recruitment of mitotic centrosome proteins and complexes': 4,
#  'Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs)': 2,
#  'Regulation of PLK1 Activity at G2/M Transition': 4,
#  'Regulation of lipid metabolism by Peroxisome proliferator-activated receptor alpha (PPARalpha)': 3,
#  'SNARE interactions in vesicular transport': 1,
#  'SUMOylation of chromatin organization proteins': 2,
#  'Schwann cell development': 1,
#  'Signal Transduction': 1,
#  'Signaling by Hedgehog': 1,
#  'Synthesis and degradation of ketone bodies': 1,
#  'Synthesis of Ketone Bodies': 2,
#  'Thyroid hormone signaling pathway': 2,
#  'Transcriptional misregulation in cancer': 1,
#  'Transcriptional regulation of white adipocyte differentiation': 2,
#  'Ubiquitin mediated proteolysis': 1,
#  'Utilization of Ketone Bodies': 2,
#  'Vesicle-mediated transport': 1,
#  'Wnt signaling pathway, planar cell polarity pathway': 1,
#  'actin cytoskeleton organization': 1,
#  'activation of innate immune response': 1,
#  'aging': 1,
#  'androgen receptor signaling pathway': 1,
#  'angiogenesis': 1,
#  'anterior/posterior pattern specification': 1,
#  'aorta morphogenesis': 1,
#  'artery morphogenesis': 1,
#  'autophagosome maturation': 1,
#  'autophagosome membrane docking': 1,
#  'axis elongation involved in somitogenesis': 1,
#  'base-excision repair': 1,
#  'blood vessel development': 1,
#  'blood vessel morphogenesis': 1,
#  'branching morphogenesis of an epithelial tube': 1,
#  'camera-type eye development': 1,
#  'canonical Wnt signaling pathway': 1,
#  'cartilage development': 1,
#  'cell adhesion mediated by integrin': 1,
#  'cell fate specification': 1,
#  'cell projection organization': 1,
#  'cell proliferation': 2,
#  'cell-cell adhesion': 1,
#  'cellular protein localization': 1,
#  'cellular protein metabolic process': 1,
#  'cellular response to dopamine': 1,
#  'cellular response to fibroblast growth factor stimulus': 1,
#  'cellular response to glucose stimulus': 1,
#  'cellular response to insulin-like growth factor stimulus': 1,
#  'cellular response to leukemia inhibitory factor': 1,
#  'cellular response to organic substance': 1,
#  'cellular response to retinoic acid': 1,
#  'cellular response to transforming growth factor beta stimulus': 1,
#  'centriole replication': 1,
#  'centrosome duplication': 1,
#  'cerebellar Purkinje cell differentiation': 1,
#  'chromatin remodeling': 1,
#  'ciliary basal body-plasma membrane docking': 4,
#  'cilium assembly': 4,
#  'cochlea morphogenesis': 1,
#  'commitment of neuronal cell to specific neuron type in forebrain': 1,
#  'common bile duct development': 1,
#  'coronary artery morphogenesis': 1,
#  'covalent chromatin modification': 1,
#  'de novo centriole assembly involved in multi-ciliated epithelial cell differentiation': 1,
#  'determination of left/right symmetry': 2,
#  'double-strand break repair via homologous recombination': 1,
#  'ear morphogenesis': 1,
#  'embryonic brain development': 2,
#  'embryonic cranial skeleton morphogenesis': 1,
#  'embryonic digit morphogenesis': 1,
#  'embryonic eye morphogenesis': 1,
#  'embryonic neurocranium morphogenesis': 1,
#  'embryonic pattern specification': 1,
#  'embryonic skeletal system development': 1,
#  'embryonic skeletal system morphogenesis': 1,
#  'embryonic viscerocranium morphogenesis': 1,
#  'enamel mineralization': 1,
#  'endoderm development': 1,
#  'epithelial cell differentiation': 1,
#  'epithelial structure maintenance': 1,
#  'excretion': 1,
#  'exocytosis': 1,
#  'extracellular matrix disassembly': 1,
#  'extracellular matrix organization': 1,
#  'eye photoreceptor cell development': 1,
#  'face morphogenesis': 1,
#  'head development': 1,
#  'heart development': 3,
#  'heart morphogenesis': 1,
#  'hematopoietic progenitor cell differentiation': 1,
#  'hindbrain development': 1,
#  'histone H3 acetylation': 1,
#  'histone acetylation': 1,
#  'histone deacetylation': 1,
#  'in utero embryonic development': 1,
#  'inner ear morphogenesis': 1,
#  'inner ear receptor cell stereocilium organization': 1,
#  'intracellular steroid hormone receptor signaling pathway': 1,
#  'ketone body biosynthetic process': 1,
#  'ketone body catabolic process': 1,
#  'lymph vessel development': 1,
#  'membrane fusion': 1,
#  'mesenchymal cell apoptotic process': 1,
#  'mesoderm development': 1,
#  'metanephros development': 1,
#  'middle ear morphogenesis': 1,
#  'motile cilium assembly': 1,
#  'multicellular organism development': 2,
#  'muscle cell fate commitment': 1,
#  'muscle organ development': 1,
#  'muscle organ morphogenesis': 1,
#  'muscle tissue morphogenesis': 1,
#  'negative regulation of Wnt signaling pathway': 1,
#  'negative regulation of apoptotic process': 1,
#  'negative regulation of autophagy': 1,
#  'negative regulation of cell differentiation': 1,
#  'negative regulation of circadian rhythm': 1,
#  'negative regulation of histone H3-K27 acetylation': 1,
#  'negative regulation of mesenchymal cell apoptotic process': 1,
#  'negative regulation of osteoclast development': 1,
#  'negative regulation of osteoclast differentiation': 1,
#  'negative regulation of protein localization to nucleus': 1,
#  'negative regulation of transcription by RNA polymerase II': 2,
#  'negative regulation of transcription regulatory region DNA binding': 1,
#  'negative regulation of transcription, DNA-templated': 2,
#  'neural crest cell migration': 1,
#  'neural tube closure': 2,
#  'neuromuscular process controlling balance': 1,
#  'neuron migration': 1,
#  'neuron projection development': 1,
#  'neutrophil degranulation': 2,
#  'non-motile cilium assembly': 1,
#  'nucleosome assembly': 1,
#  'odontogenesis of dentin-containing tooth': 1,
#  'oligodendrocyte development': 1,
#  'osteoblast development': 1,
#  'otic vesicle formation': 1,
#  'outer ear morphogenesis': 1,
#  'outflow tract morphogenesis': 1,
#  'outflow tract septum morphogenesis': 1,
#  'oxidation-reduction process': 1,
#  'palate development': 1,
#  'parathyroid gland development': 1,
#  'pattern specification process': 1,
#  'pharyngeal system development': 1,
#  'positive regulation of G2/M transition of mitotic cell cycle': 1,
#  'positive regulation of MAPK cascade': 1,
#  'positive regulation of bicellular tight junction assembly': 1,
#  'positive regulation of cell proliferation': 1,
#  'positive regulation of chromatin silencing': 1,
#  'positive regulation of defense response to virus by host': 1,
#  'positive regulation of epithelial cell proliferation': 1,
#  'positive regulation of intracellular protein transport': 1,
#  'positive regulation of mesenchymal cell proliferation': 1,
#  'positive regulation of protein phosphorylation': 1,
#  'positive regulation of tongue muscle cell differentiation': 1,
#  'positive regulation of transcription from RNA polymerase II promoter': 6,
#  'positive regulation of transcription, DNA-templated': 5,
#  'post-anal tail morphogenesis': 1,
#  'post-embryonic eye morphogenesis': 1,
#  'post-translational protein modification': 1,
#  'pronephros development': 1,
#  'protein deacetylation': 1,
#  'protein deubiquitination': 1,
#  'protein transport': 2,
#  'protein ubiquitination': 2,
#  'regulation of G2/M transition of mitotic cell cycle': 2,
#  'regulation of Wnt signaling pathway': 1,
#  'regulation of Wnt signaling pathway, planar cell polarity pathway': 1,
#  'regulation of canonical Wnt signaling pathway': 1,
#  'regulation of cellular response to growth factor stimulus': 1,
#  'regulation of establishment of protein localization': 1,
#  'regulation of hormone levels': 1,
#  'regulation of lipid metabolic process': 1,
#  'regulation of megakaryocyte differentiation': 1,
#  'regulation of molecular function': 1,
#  'regulation of organ morphogenesis': 1,
#  'regulation of receptor activity': 1,
#  'regulation of smoothened signaling pathway involved in dorsal/ventral neural tube patterning': 1,
#  'regulation of transcription from RNA polymerase II promoter': 2,
#  'regulation of transcription from RNA polymerase II promoter in response to oxidative stress': 1,
#  'regulation of transcription, DNA-templated': 1,
#  'response to methylglyoxal': 1,
#  'retina development in camera-type eye': 1,
#  'retinoic acid receptor signaling pathway': 1,
#  'rhythmic process': 1,
#  'semicircular canal morphogenesis': 1,
#  'sensory perception of sound': 1,
#  'sequestering of BMP in extracellular matrix': 1,
#  'sequestering of TGFbeta in extracellular matrix': 1,
#  'signal transduction': 1,
#  'skeletal system development': 1,
#  'social behavior': 1,
#  'soft palate development': 1,
#  'spermatid differentiation': 1,
#  'spinal cord development': 1,
#  'stem cell population maintenance': 1,
#  'synaptic vesicle fusion to presynaptic active zone membrane': 1,
#  'synaptic vesicle priming': 1,
#  'telomere maintenance': 1,
#  'telomeric D-loop disassembly': 1,
#  'thymus development': 1,
#  'thyroid gland development': 1,
#  'tongue morphogenesis': 1,
#  'transcription from RNA polymerase II promoter': 2,
#  'transcription initiation from RNA polymerase II promoter': 1,
#  'transcription, DNA-templated': 3,
#  'vagus nerve morphogenesis': 1,
#  'vesicle targeting': 1,
#  'visual behavior': 1}

# %%
# Go process params
params = {
    'wt': 'json',
    'rows': 0,
    'q': '*:*',
    'facet': 'true',
    'facet.sort': 'count',
    'facet.method': 'enum',
    'facet.mincount': '1',
    'facet.limit': '3000',
    'facet.field': 'object_label',
    'fl': 'subject, subject_label',
    'fq': [gene_or_filter,
           'relation:"RO:0002327"',
           
          ]
}

go_process = get_facet_table(solr, params)
go_process
# Out:
# {'3-hydroxybutyrate dehydrogenase activity': 1,
#  'ARF guanyl-nucleotide exchange factor activity': 1,
#  'ATP binding': 1,
#  "ATP-dependent 3'-5' DNA helicase activity": 1,
#  'DNA binding': 1,
#  'DNA binding transcription factor activity': 1,
#  'RNA binding': 1,
#  'RNA polymerase II activating transcription factor binding': 1,
#  'RNA polymerase II distal enhancer sequence-specific DNA binding': 1,
#  'RNA polymerase II proximal promoter sequence-specific DNA binding': 2,
#  'RNA polymerase II repressing transcription factor binding': 1,
#  'RNA polymerase II transcription coactivator activity': 1,
#  'RNA polymerase II transcription cofactor activity': 1,
#  'RNA polymerase II transcription corepressor activity': 1,
#  'SNAP receptor activity': 1,
#  'acetyltransferase activity': 1,
#  'annealing helicase activity': 1,
#  'beta-catenin binding': 1,
#  'bubble DNA binding': 1,
#  'calcium ion binding': 1,
#  'chromatin binding': 3,
#  'extracellular matrix constituent conferring elasticity': 1,
#  'extracellular matrix structural constituent': 1,
#  'four-way junction helicase activity': 1,
#  'helicase activity': 1,
#  'heparin binding': 1,
#  'histone acetyltransferase activity': 1,
#  'hormone activity': 1,
#  'identical protein binding': 2,
#  'integrin binding': 1,
#  'ligand-dependent nuclear receptor transcription coactivator activity': 1,
#  'metal ion binding': 2,
#  'oxidized purine DNA binding': 1,
#  'protein C-terminus binding': 1,
#  'protein binding': 12,
#  'protein complex binding': 3,
#  'protein deacetylase activity': 1,
#  'protein domain specific binding': 1,
#  'protein homodimerization activity': 1,
#  'protein kinase binding': 1,
#  'receptor activity': 1,
#  'sequence-specific DNA binding': 2,
#  'structural molecule activity': 1,
#  'syntaxin binding': 1,
#  'telomeric D-loop binding': 1,
#  'thiol-dependent ubiquitinyl hydrolase activity': 1,
#  'thyroid hormone receptor binding': 1,
#  'transcription coactivator activity': 1,
#  'transcription cofactor activity': 1,
#  'transcription factor binding': 1,
#  'transcription regulatory region sequence-specific DNA binding': 1,
#  'transcriptional activator activity, RNA polymerase II proximal promoter sequence-specific DNA binding': 2,
#  'ubiquitin protein ligase activity': 1,
#  'ubiquitin-protein transferase activity': 1,
#  'vitamin D receptor binding': 1}

# %%
# pathway params
params = {
    'wt': 'json',
    'rows': 0,
    'q': '*:*',
    'facet': 'true',
    'facet.sort': 'count',
    'facet.method': 'enum',
    'facet.mincount': '1',
    'facet.limit': '3000',
    'facet.field': 'object_label',
    'fl': 'subject, subject_label',
    'fq': [gene_or_filter,
           'object_category:"pathway"',
           
          ]
}

pathways = get_facet_table(solr, params)
pathways
# Out:
# {'AURKA Activation by TPX2': 2,
#  'Adaptive Immune System': 1,
#  'Anchoring of the basal body to the plasma membrane': 4,
#  'Antigen processing: Ubiquitination & Proteasome degradation': 1,
#  'Autophagy - animal': 1,
#  'Butanoate metabolism': 1,
#  'Cell Cycle': 2,
#  'Cell Cycle, Mitotic': 2,
#  'Centrosome maturation': 2,
#  'Chromatin modifying enzymes': 1,
#  'Chromatin organization': 1,
#  'Cilium Assembly': 4,
#  'Class I MHC mediated antigen processing & presentation': 1,
#  'Degradation of the extracellular matrix': 1,
#  'Developmental Biology': 1,
#  'Elastic fibre formation': 1,
#  'Epigenetic regulation of gene expression': 1,
#  'Extracellular matrix organization': 1,
#  'Factors involved in megakaryocyte development and platelet production': 1,
#  'Fatty acid, triacylglycerol, and ketone body metabolism': 3,
#  'G2/M Transition': 2,
#  'Gene Expression': 2,
#  'Generic Transcription Pathway': 1,
#  'HATs acetylate histones': 1,
#  "Hedgehog 'off' state": 1,
#  'Hemostasis': 1,
#  "Huntington's disease": 1,
#  'Immune System': 3,
#  'Innate Immune System': 2,
#  'Integrin cell surface interactions': 1,
#  'Intra-Golgi and retrograde Golgi-to-ER traffic': 1,
#  'Intra-Golgi traffic': 1,
#  'Ketone body metabolism': 1,
#  'Loss of Nlp from mitotic centrosomes': 2,
#  'Loss of proteins required for interphase microtubule organization from the centrosome': 2,
#  'Membrane Trafficking': 1,
#  'Metabolic pathways': 1,
#  'Metabolism': 3,
#  'Metabolism of lipids and lipoproteins': 3,
#  'Mitotic G2-G2/M phases': 2,
#  'Molecules associated with elastic fibres': 1,
#  'Negative epigenetic regulation of rRNA expression': 1,
#  'Neutrophil degranulation': 2,
#  'NoRC negatively regulates rRNA expression': 1,
#  'Organelle biogenesis and maintenance': 4,
#  'PPARA activates gene expression': 1,
#  'Post-translational protein phosphorylation': 1,
#  'RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function': 1,
#  'RUNX2 regulates osteoblast differentiation': 1,
#  'Recruitment of NuMA to mitotic centrosomes': 2,
#  'Recruitment of mitotic centrosome proteins and complexes': 2,
#  'Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs)': 1,
#  'Regulation of PLK1 Activity at G2/M Transition': 2,
#  'Regulation of lipid metabolism by Peroxisome proliferator-activated receptor alpha (PPARalpha)': 2,
#  'SNARE interactions in vesicular transport': 1,
#  'SUMOylation of chromatin organization proteins': 1,
#  'Signal Transduction': 1,
#  'Signaling by Hedgehog': 1,
#  'Synthesis and degradation of ketone bodies': 1,
#  'Synthesis of Ketone Bodies': 1,
#  'Thyroid hormone signaling pathway': 2,
#  'Transcriptional misregulation in cancer': 1,
#  'Transcriptional regulation of white adipocyte differentiation': 1,
#  'Ubiquitin mediated proteolysis': 1,
#  'Utilization of Ketone Bodies': 1,
#  'Vesicle-mediated transport': 1}

# %%
# TODO GO term enrichment with ontobio
