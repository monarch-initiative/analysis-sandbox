# %%
import requests
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

GOLR_URL = 'https://solr.monarchinitiative.org/solr/golr/select'
SEARCH_URL = 'https://solr.monarchinitiative.org/solr/search/select'

### 
# What are all the human genes with

# Set of all human genes in monarch
human_genes = set()

# Set of all genes with ortholog-phenotype associations
ortho_pheno_genes = set()

# Set of all human genes with data (minus homology)
human_genes_data = set()

# Get all human genes
# Schema yaml is here: 
# https://github.com/monarch-initiative/monarch-app/blob/master/conf/golr-views/monarch-search-config.yaml

filters = [
    'taxon:"{0}"'.format("NCBITaxon:9606"),
    'category:"gene"',
]

search_params = {
    'wt': 'json',
    'q': '*:*',
    'fq': filters,
    'fl': 'id',
    'rows': 1000,
    'start': 0
}

resultCount = search_params['rows']

while search_params['start'] < resultCount:
    solr_request = requests.get(SEARCH_URL, params=search_params)
    response = solr_request.json()
    resultCount = response['response']['numFound']
    
    for doc in response['response']['docs']:
        human_genes.add(doc['id'])
        
    search_params['start'] += search_params['rows']
    

#print(human_genes[:][0:5])
print(len(human_genes))
# Out:
# 39675

# %%
# Get all human genes with data in golr
# schema here: 
# https://github.com/monarch-initiative/monarch-app/blob/master/conf/golr-views/oban-config.yaml

filters = [
    'subject_taxon:"{0}"'.format("NCBITaxon:9606"),
    'subject_category:"gene"',
    '-relation_closure:"RO:HOM0000001"'
]

golr_params = {
    'wt': 'json',
    'q': '*:*',
    'fq': filters,
    'fl': 'subject',
    'rows': 1000,
    'start': 0
}

resultCount = golr_params['rows']

while golr_params['start'] < resultCount:
    solr_request = requests.get(GOLR_URL, params=golr_params)
    response = solr_request.json()
    resultCount = response['response']['numFound']
    
    for doc in response['response']['docs']:
        human_genes_data.add(doc['subject'])
        
    if golr_params['start'] % 100000 == 0:
        logger.info("Processed {} documents".format(golr_params['start']))
        
    golr_params['start'] += golr_params['rows']
    

#print(human_genes_data[:][0:5])
print(len(human_genes_data))
# Out:
# INFO:__main__:Processed 0 documents
# INFO:__main__:Processed 10000 documents
# INFO:__main__:Processed 20000 documents
# INFO:__main__:Processed 30000 documents
# INFO:__main__:Processed 40000 documents
# INFO:__main__:Processed 50000 documents
# INFO:__main__:Processed 60000 documents
# INFO:__main__:Processed 70000 documents
# INFO:__main__:Processed 80000 documents
# INFO:__main__:Processed 90000 documents
# INFO:__main__:Processed 100000 documents
# INFO:__main__:Processed 110000 documents
# INFO:__main__:Processed 120000 documents
# INFO:__main__:Processed 130000 documents
# INFO:__main__:Processed 140000 documents
# INFO:__main__:Processed 150000 documents
# INFO:__main__:Processed 160000 documents
# INFO:__main__:Processed 170000 documents
# INFO:__main__:Processed 180000 documents
# INFO:__main__:Processed 190000 documents
# INFO:__main__:Processed 200000 documents
# INFO:__main__:Processed 210000 documents
# INFO:__main__:Processed 220000 documents
# INFO:__main__:Processed 230000 documents
# INFO:__main__:Processed 240000 documents
# INFO:__main__:Processed 250000 documents
# INFO:__main__:Processed 260000 documents
# INFO:__main__:Processed 270000 documents
# INFO:__main__:Processed 280000 documents
# INFO:__main__:Processed 290000 documents
# INFO:__main__:Processed 300000 documents
# INFO:__main__:Processed 310000 documents
# INFO:__main__:Processed 320000 documents
# INFO:__main__:Processed 330000 documents
# INFO:__main__:Processed 340000 documents
# INFO:__main__:Processed 350000 documents
# INFO:__main__:Processed 360000 documents
# INFO:__main__:Processed 370000 documents
# INFO:__main__:Processed 380000 documents
# INFO:__main__:Processed 390000 documents
# INFO:__main__:Processed 400000 documents
# INFO:__main__:Processed 410000 documents
# INFO:__main__:Processed 420000 documents
# INFO:__main__:Processed 430000 documents
# INFO:__main__:Processed 440000 documents
# INFO:__main__:Processed 450000 documents
# INFO:__main__:Processed 460000 documents
# INFO:__main__:Processed 470000 documents
# INFO:__main__:Processed 480000 documents
# INFO:__main__:Processed 490000 documents
# INFO:__main__:Processed 500000 documents
# INFO:__main__:Processed 510000 documents
# INFO:__main__:Processed 520000 documents
# INFO:__main__:Processed 530000 documents
# INFO:__main__:Processed 540000 documents
# INFO:__main__:Processed 550000 documents
# INFO:__main__:Processed 560000 documents
# INFO:__main__:Processed 570000 documents
# INFO:__main__:Processed 580000 documents
# INFO:__main__:Processed 590000 documents
# INFO:__main__:Processed 600000 documents
# INFO:__main__:Processed 610000 documents
# INFO:__main__:Processed 620000 documents
# INFO:__main__:Processed 630000 documents
# INFO:__main__:Processed 640000 documents
# INFO:__main__:Processed 650000 documents
# INFO:__main__:Processed 660000 documents
# INFO:__main__:Processed 670000 documents
# INFO:__main__:Processed 680000 documents
# INFO:__main__:Processed 690000 documents
# INFO:__main__:Processed 700000 documents
# INFO:__main__:Processed 710000 documents
# INFO:__main__:Processed 720000 documents
# INFO:__main__:Processed 730000 documents
# INFO:__main__:Processed 740000 documents
# INFO:__main__:Processed 750000 documents
# INFO:__main__:Processed 760000 documents
# INFO:__main__:Processed 770000 documents
# INFO:__main__:Processed 780000 documents
# INFO:__main__:Processed 790000 documents
# INFO:__main__:Processed 800000 documents
# INFO:__main__:Processed 810000 documents
# INFO:__main__:Processed 820000 documents
# INFO:__main__:Processed 830000 documents
# INFO:__main__:Processed 840000 documents
# INFO:__main__:Processed 850000 documents
# INFO:__main__:Processed 860000 documents
# INFO:__main__:Processed 870000 documents
# INFO:__main__:Processed 880000 documents
# INFO:__main__:Processed 890000 documents
# INFO:__main__:Processed 900000 documents
# INFO:__main__:Processed 910000 documents
# INFO:__main__:Processed 920000 documents
# INFO:__main__:Processed 930000 documents
# INFO:__main__:Processed 940000 documents
# INFO:__main__:Processed 950000 documents
# INFO:__main__:Processed 960000 documents
# INFO:__main__:Processed 970000 documents
# INFO:__main__:Processed 980000 documents
# INFO:__main__:Processed 990000 documents
# INFO:__main__:Processed 1000000 documents
# INFO:__main__:Processed 1010000 documents
# INFO:__main__:Processed 1020000 documents
# INFO:__main__:Processed 1030000 documents
# INFO:__main__:Processed 1040000 documents
# INFO:__main__:Processed 1050000 documents
# INFO:__main__:Processed 1060000 documents
# INFO:__main__:Processed 1070000 documents
# INFO:__main__:Processed 1080000 documents
# INFO:__main__:Processed 1090000 documents
# INFO:__main__:Processed 1100000 documents
# INFO:__main__:Processed 1110000 documents
# INFO:__main__:Processed 1120000 documents
# INFO:__main__:Processed 1130000 documents
# INFO:__main__:Processed 1140000 documents
# INFO:__main__:Processed 1150000 documents
# INFO:__main__:Processed 1160000 documents
# INFO:__main__:Processed 1170000 documents
# INFO:__main__:Processed 1180000 documents
# INFO:__main__:Processed 1190000 documents
# INFO:__main__:Processed 1200000 documents
# INFO:__main__:Processed 1210000 documents
# INFO:__main__:Processed 1220000 documents
# INFO:__main__:Processed 1230000 documents
# INFO:__main__:Processed 1240000 documents
# INFO:__main__:Processed 1250000 documents
# INFO:__main__:Processed 1260000 documents
# INFO:__main__:Processed 1270000 documents
# INFO:__main__:Processed 1280000 documents
# INFO:__main__:Processed 1290000 documents
# INFO:__main__:Processed 1300000 documents
# INFO:__main__:Processed 1310000 documents
# INFO:__main__:Processed 1320000 documents
# INFO:__main__:Processed 1330000 documents
# INFO:__main__:Processed 1340000 documents
# INFO:__main__:Processed 1350000 documents
# INFO:__main__:Processed 1360000 documents
# INFO:__main__:Processed 1370000 documents
# INFO:__main__:Processed 1380000 documents
# INFO:__main__:Processed 1390000 documents
# INFO:__main__:Processed 1400000 documents
# INFO:__main__:Processed 1410000 documents
# 28613

# %%
# Get all genes with ortholog phenotype associations

filters = [
    'subject_category:"gene"',
    'object_category:"phenotype"'
]

golr_params = {
    'wt': 'json',
    'q': '*:*',
    'fq': filters,
    'fl': 'subject_ortholog_closure',
    'rows': 1000,
    'start': 0
}

resultCount = golr_params['rows']

while golr_params['start'] < resultCount:
    solr_request = requests.get(GOLR_URL, params=golr_params)
    response = solr_request.json()
    resultCount = response['response']['numFound']
    
    for doc in response['response']['docs']:
        if 'subject_ortholog_closure' in doc:
            for gene in doc['subject_ortholog_closure']:
                ortho_pheno_genes.add(gene)
        
    if golr_params['start'] % 100000 == 0:
        logger.info("Processed {} documents".format(golr_params['start']))
        
    golr_params['start'] += golr_params['rows']
    

#print(ortho_pheno_genes[:][0:5])
print(len(ortho_pheno_genes))
# Out:
# INFO:__main__:Processed 0 documents
# INFO:__main__:Processed 100000 documents
# INFO:__main__:Processed 200000 documents
# INFO:__main__:Processed 300000 documents
# INFO:__main__:Processed 400000 documents
# INFO:__main__:Processed 500000 documents
# INFO:__main__:Processed 600000 documents
# INFO:__main__:Processed 700000 documents
# 209594

# %%
### We want the intersection of all human_genes and ortho_pheno_genes
### Union of the above and human_genes_data

human_with_op = ortho_pheno_genes.intersection(human_genes)

human_genes_w_data = human_genes_data.union(human_with_op)


print(len(human_genes_w_data))

file = open("/home/kshefchek/gene_list.txt", 'w')

for gene in human_genes_w_data:
    file.write("{}\n".format(gene))
# Out:
# 28653

# %%
#!/bin/bash

grep -P '^NCBIGene' gene_list.txt >genes_only_entrez.txt
